# %% [markdown]
# # <font color ='green'> <center > Python - Lecture 01

# %% [markdown]
# ## <font color ='green'>Varibles

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <font color='green'> <h3> <center> Python - Strings </center> </h1> </font>

# %%
"this is string" # create a string
# Out:
# 'this is string'

# %%
'this is string'
# Out:
# 'this is string'

# %%
my_str = 'string in single656 quotes'  # single quotes can be used around characters

# %%
my_str

# %%
type(my_str)
# Out:
# str

# %%
temp=5
temp2="5"
temp3='5'

# %%
type(temp)
# Out:
# int

# %%
type(temp2)
# Out:
# str

# %%
type(temp3)
# Out:
# str

# %%
var="I'm Hero"

# %%
var
# Out:
# "I'm Hero"

# %%
print(var)
# Out:
# I'm Hero

# %%
my_str2 = "string in double quotes"  # double quotes can be used around characters

# %%
my_str3 = """string is spread 
acroos multiple lines"""  # triple quotes can be used to create multi line strings

# %%
string_with_spaces = " x y 1 2 3 " #string can have spaces in it

# %%
string_with_special_characters = "#$%@"

# %%
empty_string = ''  #empty string has nothing in it

# %% [markdown]
# view empty_string

# %%
empty_string
# Out:
# ''

# %%
len('this is string')
# Out:
# 14

# %%
len(empty_string)  # len can be use to determine the length of string
# Out:
# 0

# %%
len(my_str)
# Out:
# 23

# %% [markdown]
# <font color='green'> <h3> <center> <b>Concatenation and Repetition<b> </center> </h1> </font>

# %% [markdown]
# 1. <B> Concat (+) String

# %%
# Concatenate two string
str1= "Plus(+) symbol"
str2=" is used to join two or more string "
str1+str2
# Out:
# 'Plus(+) symbol is used to join two or more string '

# %% [markdown]
# 2. <B> Repetition String

# %%
#string repetition= same string multiple times
"hi "*3
# Out:
# 'hi hi hi '

# %% [markdown]
# <font color='green'> <h3> <center> Strings Functions </center> </h1> </font>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. <B> Upper

# %%
#string to upper case
str2.upper()
# Out:
# ' IS USED TO JOIN TWO OR MORE STRING '

# %% [markdown]
# 2. <B> Capitalize

# %%
#string to capitalize 
##capitalize() method converts the first character of a string to a capital (uppercase) letter.
"hi i am rohit. hi hi bye.".capitalize()
# Out:
# 'Hi i am rohit. hi hi bye.'

# %%
# when first character is space
str2.capitalize()
# Out:
# ' is used to join two or more string '

# %% [markdown]
# 3. <B> Lower

# %%
#string to lower
"HELLO FRIENDS I AM HERE".lower()
# Out:
# 'hello friends i am here'

# %% [markdown]
# 4. <B> Casefold

# %%
# Casefold - This method is similar to the lower() method, but the casefold() method is stronger, more aggressive,
# meaning that it will convert more characters into lower case, 
# and will find more matches when comparing two strings 
# and both are converted using the casefold() method.

"HELLO FRIENDS I AM HERE".casefold()
# Out:
# 'hello friends i am here'

# %% [markdown]
# 5. <B> Title </B> The title() method returns a string where the first character in every word is upper case.

# %%
"HELLO FRIENDS I AM HERE".title()
# Out:
# 'Hello Friends I Am Here'

# %% [markdown]
# 6. <B> Count

# %%
#Count function returns the number of occurrences of a substring in the given string.
str3="We all are learning the python coding"
str3.count("h")
# Out:
# 2

# %%
str3.count("l",0,5)
#str3.count("l",0,6)
# Out:
# 1

# %% [markdown]
# 7. <B> Encode

# %%
#encode() method encodes the string, using the specified encoding. If no encoding is specified, UTF-8 will be used.
"My name is Ståle".encode(encoding="ascii",errors="ignore")
# Out:
# b'My name is Stle'

# %%
"My name is Ståle".encode(encoding="ascii",errors="replace")
# Out:
# b'My name is St?le'

# %% [markdown]
# 8. <B> Endswith

# %%
str3="We all are learning the python coding"
str3.endswith("coding")
# Out:
# True

# %%
str3.endswith("g")
# Out:
# True

# %%
str3.endswith("G")
# Out:
# False

# %% [markdown]
# 9. <B> Expandtabs

# %%
#The expandtabs() method sets the tab size to the specified number of whitespaces
"hi\twelcome".expandtabs(1)
# Out:
# 'hi welcome'

# %%
"hi\twelcome".expandtabs(10)
# Out:
# 'hi        welcome'

# %% [markdown]
# 10. <B> Find </B>
#
#     ( refer rfind)

# %%
# find() method finds the first occurrence of the specified value. The find() method returns -1 if the value is not found.
str3.find("g")
# Out:
# 18

# %%
str3.find("Coding")
# Out:
# -1

# %%
str3.find("coding")
# Out:
# 31

# %% [markdown]
# 11. <B> Format

# %%
#The format() method formats the specified value(s) and insert them inside the string's placeholder.
str3.format()
# Out:
# 'We all are learning the python coding'

# %%
"My name is {fname}, I'm from {city}".format(fname = "Rohit", city = 'noida',lname="srivastava" )
# Out:
# "My name is Rohit, I'm from noida"

# %%
"My name is {0}, I'm {1}".format("John",36,'srivastava')
# Out:
# "My name is John, I'm 36"

# %%
"My name is {} {}, I'm {}".format("John",'John',36,)
# Out:
# "My name is John John, I'm 36"

# %%
"My name is {} {}, I'm {} ".format("John",'John',36,)
# Out:
# "My name is John John, I'm 36 "

# %% [markdown]
# 12. <B> Format Map

# %%
#format_map() method is an inbuilt function in Python, which is used to return a dictionary key’s value.

# input stored in variable a.
a = {'x':'John', 'y':'Wick'}

# Use of format_map() function
print("{x}'s last name is {y}".format_map(a))
# Out:
# John's last name is Wick

# %% [markdown]
# 13. <B> Index

# %%
str3.index("coding")
# Out:
# 31

# %%
#str3.index("Coding")

# %% [markdown]
# 14. <B> Is alphabet or number

# %%
str3.isalnum()
# Out:
# False

# %%
"01Hello".isalnum()
# Out:
# True

# %%
"01".isalnum()
# Out:
# True

# %%
"hello".isalnum()
# Out:
# True

# %%
"hello?".isalnum()
# Out:
# False

# %% [markdown]
# 15. <B> Is alphabet

# %%
str3
# Out:
# 'We all are learning the python coding'

# %%
#str3.isalpha()

# %%
"We all".isalpha()
# Out:
# False

# %%
#'Weal'.isalpha()

# %% [markdown]
# 16. <B> Isascii </B>- method returns True if all the characters are ascii characters  (a-z) and (0-9).

# %%
str3.isascii()
# Out:
# True

# %%
"090".isascii()
# Out:
# True

# %%
"π".isascii()
# Out:
# False

# %% [markdown]
# 17. <B> Is Decimal

# %%
#isdecimal() method returns True if all the characters are decimals (0-9).
str3.isdecimal()
# Out:
# False

# %%
#"0.00".isdecimal()

# %%
#"0".isdecimal()

# %% [markdown]
# 19. <B> Is Digit

# %%
str3.isdigit()
# Out:
# False

# %%
"0".isdigit()
# Out:
# True

# %%
"0.00".isdigit()
# Out:
# False

# %% [markdown]
# 19. <B> Is Numeric

# %%
"0".isnumeric()
# Out:
# True

# %%
"0.00".isnumeric()
# Out:
# False

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 20. <B> Isidentfier()

# %%
# The isidentifier() method returns True if the string is a valid identifier, otherwise False.

# A string is considered a valid identifier if it only contains 
#         alphanumeric letters (a-z) 
#         or (0-9)
#         or underscores (_).
        
# A valid identifier cannot start with a number, or contain any spaces.

# %%
"MyFolder".isidentifier()
# Out:
# True

# %%
"1002".isidentifier()
# Out:
# False

# %%
"_".isidentifier()
# Out:
# True

# %%
"MyFolder_1002".isidentifier()
# Out:
# True

# %%
"_MyFolder".isidentifier()
# Out:
# True

# %%
"1008_MyFolder".isidentifier()
# Out:
# False

# %%
"_My Folder".isidentifier()
# Out:
# False

# %% [markdown]
# 21. <B> Islower()

# %%
str3.islower()
# Out:
# False

# %%
"hi i am rohit srivastava".islower()
# Out:
# True

# %% [markdown]
# 22. <B> IsPrintable </B>   method returns True if all the characters are printable, otherwise False.

# %%
str3.isprintable()
# Out:
# True

# %%
"π∟".isprintable()
# Out:
# True

# %%
"Hello!\nAre you #1?".isprintable()
# Out:
# False

# %%
"\t\r\n".isprintable()
# Out:
# False

# %% [markdown]
# 23. <B> Isspaces() </B>  method returns True if all the characters in a string are whitespaces, otherwise False.

# %%
str3.isspace()
# Out:
# False

# %%
"    ".isspace()
# Out:
# True

# %% [markdown]
# 24. <B> Istitle() </B>  returns True if all words in a text start with a upper case letter, AND the rest of the word are lower case letters, otherwise False.

# %%
"HELLO, AND WELCOME TO MY WORLD".istitle()
# Out:
# False

# %%
"Hello".istitle()
# Out:
# True

# %%
"0022  34 556 Names".istitle()
# Out:
# True

# %%
"This Is %'!?".istitle()
# Out:
# True

# %% [markdown]
# 25. <B> Isupper </B> The center() method will center align the string, using a specified character (space is default) as the fill character.

# %%
str3.isupper()
# Out:
# False

# %%
"HI I AM IN UPPER 09234".isupper()
# Out:
# True

# %%
"HI I AM IN lowerupper 09234".isupper()
# Out:
# False

# %% [markdown]
# 26. <B> Center </B> The center() method will center align the string, using a specified character (space is default) as the fill character.

# %%
"hi".center(5)
# Out:
# '  hi '

# %%
"HELLO Friends".center(5)
# Out:
# 'HELLO Friends'

# %% [markdown]
# 27. <B> Join </B>

# %% [markdown]
# 28. <B> ljust </B>   method will left align the string, using a specified character (space is default) as the fill character.

# %%
txt = "banana"

x = txt.ljust(20, " ")

print(x)
# Out:
# banana

# %%
len(x)
# Out:
# 20

# %% [markdown]
# 29. <B> Rstrip </B>   method removes any trailing characters (characters at the end a string)

# %%
" Rohit Srivastava       ".rstrip()
# Out:
# ' Rohit Srivastava'

# %% [markdown]
# 30. <B> Lstrip </B>   method removes any leading characters (characters at the begining a string)

# %%
" Rohit Srivastava       ".lstrip()
# Out:
# 'Rohit Srivastava       '

# %% [markdown]
# 31. <B> Partition </B>   The partition() method searches for a specified string, and splits the string into a tuple containing three elements.
#
# <B> Rpartition </B> method searches for the last occurrence of a specified string, and splits the string into a tuple containing three elements.

# %%
# The first element contains the part before the specified string.

# The second element contains the specified string.

# The third element contains the part after the string.

str3
# Out:
# 'We all are learning the python coding'

# %%
str3.partition("are")
# Out:
# ('We all ', 'are', ' learning the python coding')

# %%
str3.rpartition("are")
# Out:
# ('We all ', 'are', ' learning the python coding')

# %%
#str3.partition("t")

# %%
#str3.rpartition("t")

# %% [markdown]
# 32. <B> Removeprefix </B> function removes the prefix and returns the rest of the string.

# %%
str3.removeprefix("We")
# Out:
# ' all are learning the python coding'

# %%
str3.removeprefix("We all")
# Out:
# ' are learning the python coding'

# %%
str3.removeprefix("e all")
# Out:
# 'We all are learning the python coding'

# %% [markdown]
# 33. <B> Removesuffix </B> function removes the suffix and returns the rest of the string. If the suffix string is not found then it returns the original string.
#
# str.removesuffix(suffix, /)

# %%
str3.removesuffix("coding")
# Out:
# 'We all are learning the python '

# %% [markdown]
# 34. <B> Replace </B> method replaces a specified phrase with another specified phrase.
#
#
#  <I> string.replace ( oldvalue, newvalue, count)

# %%
txt = "1 1 was a race horse, two two was 1 too."

# %%
txt.replace("1", "333")
# Out:
# '333 333 was a race horse, two two was 333 too.'

# %%
txt.replace("1", "333", 2) # using count parameter
# Out:
# '333 333 was a race horse, two two was 1 too.'

# %% [markdown]
# 35. <B> rfind </B> method finds the last occurrence of the specified value.
#
# The rfind() method returns -1 if the value is not found.

# %%
str3.rfind("coding")
# Out:
# 31

# %%
str3.rfind("Z")
# Out:
# -1

# %%
#str3.index("Z")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 36. <B> rindex </B> method finds the last occurrence of the specified value.
#
# The rindex() method raises an exception if the value is not found.

# %%
str3.rindex("t")
# Out:
# 26

# %%
str3.index("t")
# Out:
# 20

# %%
str3
# Out:
# 'We all are learning the python coding'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 37. <B> rjust </B> method will right align the string, using a specified character (space is default) as the fill character.

# %%
str3.rjust(50)
# Out:
# '             We all are learning the python coding'

# %% [markdown]
# 38. <B> Rsplit </B> method splits a string into a list, starting from the right.
#
# <B> string.rsplit( separator ,  maxsplit)

# %%
"apple, banana, cherry".rsplit(", ")
# Out:
# ['apple', 'banana', 'cherry']

# %%
"apple, banana, cherry".rsplit(", ", 1)
# Out:
# ['apple, banana', 'cherry']

# %%
"apple, banana, cherry".rsplit(", ", 0)
# Out:
# ['apple, banana, cherry']

# %% [markdown]
# 39. <B> Split </B> method splits a string into a list, starting from the left.
#
# <B> string.rsplit( separator ,  <I> maxsplit </I>)

# %%
"apple, banana, cherry".split(", ")
# Out:
# ['apple', 'banana', 'cherry']

# %%
"apple, banana, cherry".split(", ", 1)
# Out:
# ['apple', 'banana, cherry']

# %%
"apple, banana, cherry".split(", ", 0)
# Out:
# ['apple, banana, cherry']

# %% [markdown]
# 37. <B> splitlines() </B> method splits a string into a list. The splitting is done at line breaks.

# %%
"hi 1line. \n Hello 2nd Line \n .Bye \n \r Bye".splitlines(0)
# Out:
# ['hi 1line. ', ' Hello 2nd Line ', ' .Bye ', ' ', ' Bye']

# %%
"hi 1line. \n Hello 2nd Line \n .Bye \n \r Bye".splitlines(1)
# Out:
# ['hi 1line. \n', ' Hello 2nd Line \n', ' .Bye \n', ' \r', ' Bye']

# %%
"hi 1line. \n Hello 2nd Line \n .Bye \n \r Bye".splitlines(True)
# Out:
# ['hi 1line. \n', ' Hello 2nd Line \n', ' .Bye \n', ' \r', ' Bye']

# %%
"hi 1line. \n Hello 2nd Line \n .Bye \n \r Bye".splitlines(False)
# Out:
# ['hi 1line. ', ' Hello 2nd Line ', ' .Bye ', ' ', ' Bye']

# %% [markdown]
# 40. <B> startswith() </B> method returns True if the string starts with the specified value, otherwise False.
#
# <B> string.startswith(value, <I>start, end </I>)

# %%
str3.startswith("We")
# Out:
# True

# %%
str3.startswith("We",5,35)
# Out:
# False

# %%
str3.startswith("We",6,5666)
# Out:
# False

# %% [markdown]
# 41. <B> swapcase() </B> method returns a string where all the upper case letters are lower case and vice versa.

# %%
str3.swapcase()
# Out:
# 'wE ALL ARE LEARNING THE PYTHON CODING'

# %%
"Upper".swapcase()
# Out:
# 'uPPER'

# %%
"loweR".swapcase()
# Out:
# 'LOWEr'

# %%
str3.islower()
# Out:
# False
